# %% [markdown]
# * **In this Notebook, we are trying to approach the task of semantic segmentation, classifying each pixel in an image from a set of classes that are previously defined.**
#
# * **Our main goal in this task is to take an image of size (Width x Height x 3) and generate a (Width x Height) matrix containing the predicted class corresponding to each pixel in the image.**

# %% [markdown]
# As the first step in any computer vision task, we are going to prepare the dataset.
#
# In this notebook, we will use [this dataset](https://www.kaggle.com/bulentsiyah/semantic-drone-dataset)

# %% [markdown]
# So, Let's first import the dependencies.

# %%
# Importing all the required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import os
from keras.utils import Sequence, to_categorical, plot_model
from keras.layers import Conv2D, Dropout, MaxPooling2D, UpSampling2D, concatenate, Input
from keras.models import Model
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Now, Let's visualize the images in the dataset

# %%
path = '/kaggle/input/semantic-drone-dataset/dataset/semantic_drone_dataset/'
img = cv2.imread(path + 'original_images/001.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
mask = cv2.imread(path + 'label_images_semantic/001.png', cv2.IMREAD_GRAYSCALE)
#mask = mask.cvtColor(img, cv2.COLOR_BGR2RGB)
fig, axs = plt.subplots(1, 2, figsize=(20, 10))
axs[0].imshow(img)
axs[1].imshow(mask)

# %%
print('Image Dimensions are: ', img.shape)
print('Label Dimensions are: ', mask.shape)
# Out:
# Image Dimensions are:  (4000, 6000, 3)
# Label Dimensions are:  (4000, 6000)

# %% [markdown]
# **DATA Preprocessing**

# %% [markdown]
# Let's Prepare our dataset for the training

# %%
# Prepare the Images
X = []
for filename in sorted(os.listdir(path + 'original_images/')):
    a = cv2.imread(path + 'original_images/' + filename)
    a = cv2.cvtColor(a, cv2.COLOR_BGR2RGB)
    a = cv2.resize(a, (256, 256))
    a = a / 255
    X.append(a)
    
X = np.array(X)

# Prepare the Labels
Y = []
for filename in sorted(os.listdir(path + 'label_images_semantic/')):
    a = cv2.imread(path + 'label_images_semantic/' + filename, cv2.IMREAD_GRAYSCALE)
    a = cv2.resize(a, (256, 256))
    Y.append(a)
    
Y = np.array(Y)
Yc = to_categorical(Y)

# %%
print(X.shape)
print(Yc.shape)
fig, axs = plt.subplots(1, 2, figsize=(20, 10))
axs[0].imshow(X[1])
axs[1].imshow(Y[1])
# Out:
# (400, 256, 256, 3)
# (400, 256, 256, 23)

# %% [markdown]
# Now, Let's Split our data into training and validation.
#
# I will keep the last image as a test image to test the Model

# %%
test_image1 = X[-1]
test_label1 = Yc[-1]
test_image2 = X[-2]
test_label2 = Yc[-2]
x_train, x_val, y_train, y_val = train_test_split(X[0:-2], Yc[0:-2], test_size = 0.1)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_val.shape)
print(y_val.shape)
# Out:
# (358, 256, 256, 3)
# (358, 256, 256, 23)
# (40, 256, 256, 3)
# (40, 256, 256, 23)

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 10))
axs[0].imshow(x_train[50])
axs[1].imshow(np.argmax(y_train[50], axis=2))

# %% [markdown]
# **NOW, We are ready to create the Model, U-NET**

# %%
def unet(num_classes = 23, image_shape = (256, 256, 3)):
    # Input
    inputs = Input(image_shape)
    # Encoder Path
    conv1 = Conv2D(64, 3, activation='relu', kernel_initializer = 'he_normal', padding='same')(inputs)
    conv1 = Conv2D(64, 3, activation='relu', kernel_initializer = 'he_normal', padding='same')(conv1)
    pool1 = MaxPooling2D((2,2))(conv1)
    
    conv2 = Conv2D(128, 3, activation='relu', kernel_initializer = 'he_normal', padding='same')(pool1)
    conv2 = Conv2D(128, 3, activation='relu', kernel_initializer = 'he_normal', padding='same')(conv2)
    pool2 = MaxPooling2D((2,2))(conv2)

    conv3 = Conv2D(256, 3, activation='relu', kernel_initializer = 'he_normal', padding='same')(pool2)
    conv3 = Conv2D(256, 3, activation='relu', kernel_initializer = 'he_normal', padding='same')(conv3)
    pool3 = MaxPooling2D((2,2))(conv3)
    
    conv4 = Conv2D(512, 3, activation='relu', kernel_initializer = 'he_normal', padding='same')(pool3)
    conv4 = Conv2D(512, 3, activation='relu', kernel_initializer = 'he_normal', padding='same')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D((2,2))(drop4)
    
    conv5 = Conv2D(1024, 3, activation='relu', kernel_initializer = 'he_normal', padding='same')(pool4)
    conv5 = Conv2D(1024, 3, activation='relu', kernel_initializer = 'he_normal', padding='same')(conv5)
    drop5 = Dropout(0.5)(conv5)
    
    # Decoder Path
    up6 = Conv2D(512, 2, activation='relu', kernel_initializer='he_normal', padding='same')(UpSampling2D(size=(2,2))(drop5))
    merge6 = concatenate([up6, conv4], axis = 3)
    conv6 = Conv2D(512, 3, activation='relu', kernel_initializer='he_normal', padding='same')(merge6)
    conv6 = Conv2D(512, 3, activation='relu', kernel_initializer='he_normal', padding='same')(conv6)
    
    up7 = Conv2D(256, 2, activation='relu', kernel_initializer='he_normal', padding='same')(UpSampling2D(size=(2,2))(conv6))
    merge7 = concatenate([up7, conv3], axis = 3)
    conv7 = Conv2D(256, 3, activation='relu', kernel_initializer='he_normal', padding='same')(merge7)
    conv7 = Conv2D(256, 3, activation='relu', kernel_initializer='he_normal', padding='same')(conv7)
    
    up8 = Conv2D(128, 2, activation='relu', kernel_initializer='he_normal', padding='same')(UpSampling2D(size=(2,2))(conv7))
    merge8 = concatenate([up8, conv2], axis = 3)
    conv8 = Conv2D(128, 3, activation='relu', kernel_initializer='he_normal', padding='same')(merge8)
    conv8 = Conv2D(128, 3, activation='relu', kernel_initializer='he_normal', padding='same')(conv8)
    
    up9 = Conv2D(64, 2, activation='relu', kernel_initializer='he_normal', padding='same')(UpSampling2D(size=(2,2))(conv8))
    merge9 = concatenate([up9, conv1], axis = 3)
    conv9 = Conv2D(64, 3, activation='relu', kernel_initializer='he_normal', padding='same')(merge9)
    conv9 = Conv2D(64, 3, activation='relu', kernel_initializer='he_normal', padding='same')(conv9)
    
    conv10 = Conv2D(num_classes, (1, 1), padding='same', activation='softmax')(conv9)
    
    model = Model(inputs, conv10)
    
    return model

# %%
model = unet()
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 64) 36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 128 147584      conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 512)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 512)  0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 1024) 9438208     conv2d_9[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 1024) 0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 1024) 0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 1024) 0           conv2d_11[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 512)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 512)  0           conv2d_14[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 256 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 256 0           conv2d_17[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 295040      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 128 147584      conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 128 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 128 0           conv2d_20[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 23) 1495        conv2d_22[0][0]
# ==================================================================================================
# Total params: 31,033,175
# Trainable params: 31,033,175
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model)

# %% [markdown]
# Reaching that point successfully, we are now ready to complie and train our model

# %% [markdown]
# Although accuracy is not the better metric while doing semantic segmentation, we will just go through this notebook.

# %%
model_checkpoint = ModelCheckpoint('unet_model.hdf5', monitor='val_loss', verbose=1, save_best_only=True)
model_earlyStopping = EarlyStopping(min_delta= 0.001, patience=30)

model.compile(optimizer='adam', loss=['categorical_crossentropy'], metrics=['accuracy'])

history = model.fit(x=x_train, y=y_train,
              validation_data=(x_val, y_val),
              batch_size=16, epochs=200,
              callbacks=[model_checkpoint, model_earlyStopping])
# Out:
# Train on 358 samples, validate on 40 samples
# Epoch 1/200
# 358/358 [==============================] - 25s 71ms/step - loss: 3.0316 - accuracy: 0.3821 - val_loss: 1.9601 - val_accuracy: 0.5146
#
# Epoch 00001: val_loss improved from inf to 1.96015, saving model to unet_model.hdf5
# Epoch 2/200
# 358/358 [==============================] - 16s 46ms/step - loss: 1.9202 - accuracy: 0.4879 - val_loss: 1.7911 - val_accuracy: 0.5297
#
# Epoch 00002: val_loss improved from 1.96015 to 1.79105, saving model to unet_model.hdf5
# Epoch 3/200
# 358/358 [==============================] - 16s 45ms/step - loss: 1.7863 - accuracy: 0.5105 - val_loss: 1.6144 - val_accuracy: 0.5546
#
# Epoch 00003: val_loss improved from 1.79105 to 1.61440, saving model to unet_model.hdf5
# Epoch 4/200
# 358/358 [==============================] - 16s 45ms/step - loss: 1.5553 - accuracy: 0.5550 - val_loss: 1.3990 - val_accuracy: 0.5926
#
# Epoch 00004: val_loss improved from 1.61440 to 1.39900, saving model to unet_model.hdf5
# Epoch 5/200
# 358/358 [==============================] - 16s 45ms/step - loss: 1.5461 - accuracy: 0.5500 - val_loss: 1.4131 - val_accuracy: 0.5919
#
# Epoch 00005: val_loss did not improve from 1.39900
# Epoch 6/200
# 358/358 [==============================] - 16s 44ms/step - loss: 1.4115 - accuracy: 0.5862 - val_loss: 1.2572 - val_accuracy: 0.6129
#
# Epoch 00006: val_loss improved from 1.39900 to 1.25719, saving model to unet_model.hdf5
# Epoch 7/200
# 358/358 [==============================] - 16s 45ms/step - loss: 1.3015 - accuracy: 0.6193 - val_loss: 1.3190 - val_accuracy: 0.6062
#
# Epoch 00007: val_loss did not improve from 1.25719
# Epoch 8/200
# 358/358 [==============================] - 16s 44ms/step - loss: 1.2999 - accuracy: 0.6143 - val_loss: 1.2029 - val_accuracy: 0.6401
#
# Epoch 00008: val_loss improved from 1.25719 to 1.20293, saving model to unet_model.hdf5
# Epoch 9/200
# 358/358 [==============================] - 16s 45ms/step - loss: 1.2054 - accuracy: 0.6359 - val_loss: 1.1047 - val_accuracy: 0.6622
#
# Epoch 00009: val_loss improved from 1.20293 to 1.10473, saving model to unet_model.hdf5
# Epoch 10/200
# 358/358 [==============================] - 16s 45ms/step - loss: 1.1565 - accuracy: 0.6512 - val_loss: 1.1657 - val_accuracy: 0.6497
#
# Epoch 00010: val_loss did not improve from 1.10473
# Epoch 11/200
# 358/358 [==============================] - 16s 44ms/step - loss: 1.1807 - accuracy: 0.6401 - val_loss: 1.0706 - val_accuracy: 0.6722
#
# Epoch 00011: val_loss improved from 1.10473 to 1.07057, saving model to unet_model.hdf5
# Epoch 12/200
# 358/358 [==============================] - 16s 44ms/step - loss: 1.1239 - accuracy: 0.6578 - val_loss: 1.0306 - val_accuracy: 0.6813
#
# Epoch 00012: val_loss improved from 1.07057 to 1.03058, saving model to unet_model.hdf5
# Epoch 13/200
# 358/358 [==============================] - 16s 44ms/step - loss: 1.1509 - accuracy: 0.6467 - val_loss: 1.1211 - val_accuracy: 0.6537
#
# Epoch 00013: val_loss did not improve from 1.03058
# Epoch 14/200
# 358/358 [==============================] - 15s 43ms/step - loss: 1.1180 - accuracy: 0.6635 - val_loss: 1.0337 - val_accuracy: 0.6953
#
# Epoch 00014: val_loss did not improve from 1.03058
# Epoch 15/200
# 358/358 [==============================] - 15s 42ms/step - loss: 1.0618 - accuracy: 0.6780 - val_loss: 1.0388 - val_accuracy: 0.6848
#
# Epoch 00015: val_loss did not improve from 1.03058
# Epoch 16/200
# 358/358 [==============================] - 15s 42ms/step - loss: 1.0191 - accuracy: 0.6919 - val_loss: 1.0366 - val_accuracy: 0.6821
#
# Epoch 00016: val_loss did not improve from 1.03058
# Epoch 17/200
# 358/358 [==============================] - 15s 42ms/step - loss: 1.0475 - accuracy: 0.6837 - val_loss: 0.9271 - val_accuracy: 0.7133
#
# Epoch 00017: val_loss improved from 1.03058 to 0.92714, saving model to unet_model.hdf5
# Epoch 18/200
# 358/358 [==============================] - 15s 42ms/step - loss: 1.0217 - accuracy: 0.6903 - val_loss: 1.0173 - val_accuracy: 0.6888
#
# Epoch 00018: val_loss did not improve from 0.92714
# Epoch 19/200
# 358/358 [==============================] - 15s 42ms/step - loss: 0.9913 - accuracy: 0.6983 - val_loss: 1.0161 - val_accuracy: 0.6969
#
# Epoch 00019: val_loss did not improve from 0.92714
# Epoch 20/200
# 358/358 [==============================] - 15s 42ms/step - loss: 0.9308 - accuracy: 0.7219 - val_loss: 0.9492 - val_accuracy: 0.7144
#
# Epoch 00020: val_loss did not improve from 0.92714
# Epoch 21/200
# 358/358 [==============================] - 15s 42ms/step - loss: 0.9702 - accuracy: 0.7054 - val_loss: 0.9320 - val_accuracy: 0.7170
#
# Epoch 00021: val_loss did not improve from 0.92714
# Epoch 22/200
# 358/358 [==============================] - 15s 42ms/step - loss: 0.9258 - accuracy: 0.7195 - val_loss: 0.8878 - val_accuracy: 0.7252
#
# Epoch 00022: val_loss improved from 0.92714 to 0.88780, saving model to unet_model.hdf5
# Epoch 23/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.8639 - accuracy: 0.7373 - val_loss: 0.9019 - val_accuracy: 0.7172
#
# Epoch 00023: val_loss did not improve from 0.88780
# Epoch 24/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.9638 - accuracy: 0.7037 - val_loss: 0.9624 - val_accuracy: 0.7154
#
# Epoch 00024: val_loss did not improve from 0.88780
# Epoch 25/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.8960 - accuracy: 0.7318 - val_loss: 0.9610 - val_accuracy: 0.7036
#
# Epoch 00025: val_loss did not improve from 0.88780
# Epoch 26/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.9669 - accuracy: 0.7073 - val_loss: 0.8886 - val_accuracy: 0.7348
#
# Epoch 00026: val_loss did not improve from 0.88780
# Epoch 27/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.9268 - accuracy: 0.7200 - val_loss: 0.8779 - val_accuracy: 0.7212
#
# Epoch 00027: val_loss improved from 0.88780 to 0.87787, saving model to unet_model.hdf5
# Epoch 28/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.8321 - accuracy: 0.7492 - val_loss: 0.8161 - val_accuracy: 0.7544
#
# Epoch 00028: val_loss improved from 0.87787 to 0.81615, saving model to unet_model.hdf5
# Epoch 29/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.7924 - accuracy: 0.7602 - val_loss: 0.7795 - val_accuracy: 0.7612
#
# Epoch 00029: val_loss improved from 0.81615 to 0.77946, saving model to unet_model.hdf5
# Epoch 30/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.7619 - accuracy: 0.7700 - val_loss: 0.7618 - val_accuracy: 0.7670
#
# Epoch 00030: val_loss improved from 0.77946 to 0.76179, saving model to unet_model.hdf5
# Epoch 31/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.7476 - accuracy: 0.7741 - val_loss: 0.8394 - val_accuracy: 0.7318
#
# Epoch 00031: val_loss did not improve from 0.76179
# Epoch 32/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.7286 - accuracy: 0.7790 - val_loss: 0.7497 - val_accuracy: 0.7686
#
# Epoch 00032: val_loss improved from 0.76179 to 0.74969, saving model to unet_model.hdf5
# Epoch 33/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.7042 - accuracy: 0.7863 - val_loss: 0.7907 - val_accuracy: 0.7597
#
# Epoch 00033: val_loss did not improve from 0.74969
# Epoch 34/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.7054 - accuracy: 0.7869 - val_loss: 0.7517 - val_accuracy: 0.7678
#
# Epoch 00034: val_loss did not improve from 0.74969
# Epoch 35/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.6831 - accuracy: 0.7932 - val_loss: 0.7674 - val_accuracy: 0.7650
#
# Epoch 00035: val_loss did not improve from 0.74969
# Epoch 36/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.6948 - accuracy: 0.7896 - val_loss: 0.6867 - val_accuracy: 0.7883
#
# Epoch 00036: val_loss improved from 0.74969 to 0.68665, saving model to unet_model.hdf5
# Epoch 37/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.6478 - accuracy: 0.8024 - val_loss: 0.6989 - val_accuracy: 0.7859
#
# Epoch 00037: val_loss did not improve from 0.68665
# Epoch 38/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.6177 - accuracy: 0.8101 - val_loss: 0.6516 - val_accuracy: 0.7982
#
# Epoch 00038: val_loss improved from 0.68665 to 0.65163, saving model to unet_model.hdf5
# Epoch 39/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.5941 - accuracy: 0.8175 - val_loss: 0.6740 - val_accuracy: 0.7962
#
# Epoch 00039: val_loss did not improve from 0.65163
# Epoch 40/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.5987 - accuracy: 0.8178 - val_loss: 0.6887 - val_accuracy: 0.7939
#
# Epoch 00040: val_loss did not improve from 0.65163
# Epoch 41/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.6592 - accuracy: 0.7987 - val_loss: 0.7614 - val_accuracy: 0.7744
#
# Epoch 00041: val_loss did not improve from 0.65163
# Epoch 42/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.7546 - accuracy: 0.7690 - val_loss: 0.7037 - val_accuracy: 0.7835
#
# Epoch 00042: val_loss did not improve from 0.65163
# Epoch 43/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.6705 - accuracy: 0.7970 - val_loss: 0.7462 - val_accuracy: 0.7725
#
# Epoch 00043: val_loss did not improve from 0.65163
# Epoch 44/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.6159 - accuracy: 0.8091 - val_loss: 0.6746 - val_accuracy: 0.7945
#
# Epoch 00044: val_loss did not improve from 0.65163
# Epoch 45/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.5993 - accuracy: 0.8164 - val_loss: 0.7134 - val_accuracy: 0.7834
#
# Epoch 00045: val_loss did not improve from 0.65163
# Epoch 46/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.6121 - accuracy: 0.8124 - val_loss: 0.6815 - val_accuracy: 0.7959
#
# Epoch 00046: val_loss did not improve from 0.65163
# Epoch 47/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.5738 - accuracy: 0.8233 - val_loss: 0.6441 - val_accuracy: 0.8050
#
# Epoch 00047: val_loss improved from 0.65163 to 0.64414, saving model to unet_model.hdf5
# Epoch 48/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.5350 - accuracy: 0.8363 - val_loss: 0.6256 - val_accuracy: 0.8132
#
# Epoch 00048: val_loss improved from 0.64414 to 0.62563, saving model to unet_model.hdf5
# Epoch 49/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.5028 - accuracy: 0.8449 - val_loss: 0.5843 - val_accuracy: 0.8249
#
# Epoch 00049: val_loss improved from 0.62563 to 0.58431, saving model to unet_model.hdf5
# Epoch 50/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.4864 - accuracy: 0.8503 - val_loss: 0.5803 - val_accuracy: 0.8254
#
# Epoch 00050: val_loss improved from 0.58431 to 0.58029, saving model to unet_model.hdf5
# Epoch 51/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.4678 - accuracy: 0.8558 - val_loss: 0.5707 - val_accuracy: 0.8292
#
# Epoch 00051: val_loss improved from 0.58029 to 0.57070, saving model to unet_model.hdf5
# Epoch 52/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.4670 - accuracy: 0.8557 - val_loss: 0.6062 - val_accuracy: 0.8221
#
# Epoch 00052: val_loss did not improve from 0.57070
# Epoch 53/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.4589 - accuracy: 0.8582 - val_loss: 0.5944 - val_accuracy: 0.8235
#
# Epoch 00053: val_loss did not improve from 0.57070
# Epoch 54/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.4479 - accuracy: 0.8613 - val_loss: 0.6097 - val_accuracy: 0.8224
#
# Epoch 00054: val_loss did not improve from 0.57070
# Epoch 55/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.4243 - accuracy: 0.8682 - val_loss: 0.5750 - val_accuracy: 0.8351
#
# Epoch 00055: val_loss did not improve from 0.57070
# Epoch 56/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.4021 - accuracy: 0.8759 - val_loss: 0.5749 - val_accuracy: 0.8336
#
# Epoch 00056: val_loss did not improve from 0.57070
# Epoch 57/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.3950 - accuracy: 0.8789 - val_loss: 0.5831 - val_accuracy: 0.8332
#
# Epoch 00057: val_loss did not improve from 0.57070
# Epoch 58/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.3856 - accuracy: 0.8813 - val_loss: 0.5764 - val_accuracy: 0.8324
#
# Epoch 00058: val_loss did not improve from 0.57070
# Epoch 59/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.3699 - accuracy: 0.8860 - val_loss: 0.5489 - val_accuracy: 0.8431
#
# Epoch 00059: val_loss improved from 0.57070 to 0.54886, saving model to unet_model.hdf5
# Epoch 60/200
# 358/358 [==============================] - 15s 42ms/step - loss: 0.3751 - accuracy: 0.8849 - val_loss: 0.5449 - val_accuracy: 0.8397
#
# Epoch 00060: val_loss improved from 0.54886 to 0.54488, saving model to unet_model.hdf5
# Epoch 61/200
# 358/358 [==============================] - 16s 45ms/step - loss: 0.3651 - accuracy: 0.8878 - val_loss: 0.5701 - val_accuracy: 0.8368
#
# Epoch 00061: val_loss did not improve from 0.54488
# Epoch 62/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.3434 - accuracy: 0.8944 - val_loss: 0.5603 - val_accuracy: 0.8424
#
# Epoch 00062: val_loss did not improve from 0.54488
# Epoch 63/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.3299 - accuracy: 0.8989 - val_loss: 0.5601 - val_accuracy: 0.8453
#
# Epoch 00063: val_loss did not improve from 0.54488
# Epoch 64/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.3211 - accuracy: 0.9013 - val_loss: 0.5660 - val_accuracy: 0.8406
#
# Epoch 00064: val_loss did not improve from 0.54488
# Epoch 65/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.3165 - accuracy: 0.9026 - val_loss: 0.5716 - val_accuracy: 0.8425
#
# Epoch 00065: val_loss did not improve from 0.54488
# Epoch 66/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.3151 - accuracy: 0.9029 - val_loss: 0.5555 - val_accuracy: 0.8415
#
# Epoch 00066: val_loss did not improve from 0.54488
# Epoch 67/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.2992 - accuracy: 0.9084 - val_loss: 0.5518 - val_accuracy: 0.8506
#
# Epoch 00067: val_loss did not improve from 0.54488
# Epoch 68/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.2767 - accuracy: 0.9155 - val_loss: 0.5611 - val_accuracy: 0.8497
#
# Epoch 00068: val_loss did not improve from 0.54488
# Epoch 69/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.2618 - accuracy: 0.9204 - val_loss: 0.5633 - val_accuracy: 0.8499
#
# Epoch 00069: val_loss did not improve from 0.54488
# Epoch 70/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.2551 - accuracy: 0.9228 - val_loss: 0.6052 - val_accuracy: 0.8453
#
# Epoch 00070: val_loss did not improve from 0.54488
# Epoch 71/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.2453 - accuracy: 0.9257 - val_loss: 0.5674 - val_accuracy: 0.8525
#
# Epoch 00071: val_loss did not improve from 0.54488
# Epoch 72/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.2327 - accuracy: 0.9298 - val_loss: 0.5991 - val_accuracy: 0.8506
#
# Epoch 00072: val_loss did not improve from 0.54488
# Epoch 73/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.2240 - accuracy: 0.9323 - val_loss: 0.6003 - val_accuracy: 0.8476
#
# Epoch 00073: val_loss did not improve from 0.54488
# Epoch 74/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.2187 - accuracy: 0.9340 - val_loss: 0.5902 - val_accuracy: 0.8492
#
# Epoch 00074: val_loss did not improve from 0.54488
# Epoch 75/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.2118 - accuracy: 0.9363 - val_loss: 0.6084 - val_accuracy: 0.8505
#
# Epoch 00075: val_loss did not improve from 0.54488
# Epoch 76/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.2017 - accuracy: 0.9396 - val_loss: 0.6237 - val_accuracy: 0.8500
#
# Epoch 00076: val_loss did not improve from 0.54488
# Epoch 77/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.1938 - accuracy: 0.9420 - val_loss: 0.5974 - val_accuracy: 0.8539
#
# Epoch 00077: val_loss did not improve from 0.54488
# Epoch 78/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.1916 - accuracy: 0.9425 - val_loss: 0.6197 - val_accuracy: 0.8524
#
# Epoch 00078: val_loss did not improve from 0.54488
# Epoch 79/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.1881 - accuracy: 0.9435 - val_loss: 0.6347 - val_accuracy: 0.8499
#
# Epoch 00079: val_loss did not improve from 0.54488
# Epoch 80/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.1839 - accuracy: 0.9449 - val_loss: 0.6332 - val_accuracy: 0.8512
#
# Epoch 00080: val_loss did not improve from 0.54488
# Epoch 81/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.1767 - accuracy: 0.9471 - val_loss: 0.6327 - val_accuracy: 0.8534
#
# Epoch 00081: val_loss did not improve from 0.54488
# Epoch 82/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.1707 - accuracy: 0.9488 - val_loss: 0.6336 - val_accuracy: 0.8517
#
# Epoch 00082: val_loss did not improve from 0.54488
# Epoch 83/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.1701 - accuracy: 0.9488 - val_loss: 0.6469 - val_accuracy: 0.8540
#
# Epoch 00083: val_loss did not improve from 0.54488
# Epoch 84/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.1694 - accuracy: 0.9491 - val_loss: 0.6509 - val_accuracy: 0.8490
#
# Epoch 00084: val_loss did not improve from 0.54488
# Epoch 85/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.2016 - accuracy: 0.9384 - val_loss: 0.6815 - val_accuracy: 0.8432
#
# Epoch 00085: val_loss did not improve from 0.54488
# Epoch 86/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.2184 - accuracy: 0.9333 - val_loss: 0.6399 - val_accuracy: 0.8416
#
# Epoch 00086: val_loss did not improve from 0.54488
# Epoch 87/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.2187 - accuracy: 0.9330 - val_loss: 0.6257 - val_accuracy: 0.8457
#
# Epoch 00087: val_loss did not improve from 0.54488
# Epoch 88/200
# 358/358 [==============================] - 16s 44ms/step - loss: 0.6821 - accuracy: 0.8189 - val_loss: 1.5369 - val_accuracy: 0.5843
#
# Epoch 00088: val_loss did not improve from 0.54488
# Epoch 89/200
# 358/358 [==============================] - 16s 44ms/step - loss: 1.3915 - accuracy: 0.5942 - val_loss: 1.4928 - val_accuracy: 0.5744
#
# Epoch 00089: val_loss did not improve from 0.54488
# Epoch 90/200
# 358/358 [==============================] - 16s 44ms/step - loss: 1.2722 - accuracy: 0.6172 - val_loss: 1.1011 - val_accuracy: 0.6694
#
# Epoch 00090: val_loss did not improve from 0.54488

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

plt.figure(figsize=(15, 15))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# Now, Let's evaluate our Model. I will use the test Image that the model had never seen before.

# %%
m1 = test_image1
pred = model.predict(np.expand_dims(m1, 0))
pred_mask = np.argmax(pred, axis=-1)
print(pred_mask.shape)
pred_mask = pred_mask[0]
print(pred_mask.shape)

m2 = test_image2
pred2 = model.predict(np.expand_dims(m2, 0))
pred_mask2 = np.argmax(pred2, axis=-1)
print(pred_mask2.shape)
pred_mask2 = pred_mask2[0]
print(pred_mask2.shape)
# Out:
# (1, 256, 256)
# (256, 256)
# (1, 256, 256)
# (256, 256)

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 10))
axs[0].imshow(m1)
axs[0].set_title('Image')
axs[1].imshow(np.argmax(test_label1, axis=-1))
axs[1].set_title('Ground Truth')
axs[2].imshow(pred_mask)
axs[2].set_title('Prediction')
# Out:
# Text(0.5, 1.0, 'Prediction')

# %%
fig, axs = plt.subplots(1, 3, figsize=(20, 10))
axs[0].imshow(m2)
axs[0].set_title('Image')
axs[1].imshow(np.argmax(test_label2, axis=-1))
axs[1].set_title('Ground Truth')
axs[2].imshow(pred_mask2)
axs[2].set_title('Prediction')
# Out:
# Text(0.5, 1.0, 'Prediction')
